# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# (Copy the YAML file and Twitter keys over)
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file 
twitter_creds = yaml.safe_load(open('API-keys.yaml', 'r').read())

# Pass your twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
# check connection is ok
print(twitter_api)

# %%
# get world wide trends first
trends_worldwide = twitter_api.trends.available()
print(len(trends_worldwide))
list_of_names = [_['name'] for _ in trends_worldwide]
print(list_of_names[0:10])
# Out:
# 467
# ['Worldwide', 'Winnipeg', 'Ottawa', 'Quebec', 'Montreal', 'Toronto', 'Edmonton', 'Calgary', 'Vancouver', 'Birmingham']

# %%
# retrieve the city in question and its woeid
ny = [_ for _ in trends_worldwide if _['name'] == 'New York']
lo = [_ for _ in trends_worldwide if _['name'] == 'London']

ny_trends = twitter_api.trends.place(_id = ny[0]['woeid'])
lo_trends = twitter_api.trends.place(_id = lo[0]['woeid'])

# %%
# place in dataframes
import pandas as pd

ny_trends_pd = pd.DataFrame(ny_trends[0]['trends'])
lo_trends_pd = pd.DataFrame(lo_trends[0]['trends'])

ny_trends_50k = ny_trends_pd[ny_trends_pd['tweet_volume'] > 100000].sort_values('tweet_volume', ascending=False)
lo_trends_50k = lo_trends_pd[ny_trends_pd['tweet_volume'] > 100000].sort_values('tweet_volume', ascending=False)
ny_trends_50k
# Out:
#                name                                                url  \
# 7       #MahsaAmini          http://twitter.com/search?q=%23MahsaAmini
# 10            Apple                  http://twitter.com/search?q=Apple
# 9           Iranian                http://twitter.com/search?q=Iranian
# 20      Puerto Rico      http://twitter.com/search?q=%22Puerto+Rico%22
# 6   Hurricane Fiona  http://twitter.com/search?q=%22Hurricane+Fiona%22
# 39             CDMX                   http://twitter.com/search?q=CDMX
# 25        Michoacán         http://twitter.com/search?q=Michoac%C3%A1n
#
#    promoted_content                  query  tweet_volume
# 7              None          %23MahsaAmini      733633.0
# 10             None                  Apple      459902.0
# 9              None                Iranian      414310.0
# 20             None      %22Puerto+Rico%22      347961.0
# 6              None  %22Hurricane+Fiona%22      131547.0
# 39             None                   CDMX      103160.0
# 25             None         Michoac%C3%A1n      100601.0

# %%
# save to csv
ny_trends_50k.to_csv('ny_trends_50k.csv')
lo_trends_50k.to_csv('lo_trends_50k.csv')

# %%
# Find common topics.
ny_trends_list = [trend['name'] for trend in ny_trends[0]['trends']]
print(ny_trends_list)
lo_trends_list =[trend['name'] for trend in lo_trends[0]['trends']]
print(lo_trends_list)
# Out:
# ['#RHOBH', '#thursdaymorning', '#VenmoMe', '#ThursdayThoughts', '#thursdayvibes', 'Snake Island', 'Daily Quordle 157', '$25 USD', 'Miles Bridges', 'Wordle 376 X', 'Happy Friday Eve', 'Good Thursday', 'Jon Voigt', 'Liz Cheney', 'NICKI EVE', 'Upper East Side', 'NATO', 'Joe Rogan', 'Jesus is Lord', 'LUMA', 'Pam Bondi', 'wooyoung', 'Richarlison', 'Tina', 'Emmett Till', 'Killing in the Name', 'Reagan Library', 'Sutton', 'Conte', 'Favre', 'Snowden', 'Diana', 'Kidney', 'Everton', 'Guatemala', 'Rage Against the Machine', 'Daily Wire', 'Cornell', 'Naylor', 'Cleaning', 'RATM', 'CERN', 'Tom Hiddleston', 'Staubach', 'Eucharist', 'NAACP', '#IOnlyAnswerMyPhoneWhen', '#SocialMediaDay', '#ThankfulThursday', '#thunderous']
# ['Putin', 'Shrewsbury', '#thismorning', 'Pele', 'Glen', 'Tottenham', 'Congolese', 'Foreign Secretary', '#rcgpac', '#MethodistConf', '#Carriegate', 'Bernie Ecclestone', 'Richarlison', 'Snake Island', 'RIP Rocky', 'Spurs', 'Everton', 'Moyes', 'Danjuma', 'Size 9', 'Captain Tom', 'Natalie McGarry', 'Size 10', 'Lingard', 'Ronaldinho', 'Kane', 'Conte', 'iPads', 'Killing in the Name', 'Romero', 'Monkey Island', 'Perisic', 'Daily Quordle 157', 'Gavin Williamson', 'Meghan', 'Dennis', 'Arlene', "O'Brien", 'Crown Estate', 'Barbados', 'Joma', 'Tom Moore', 'Foreign Office', 'wooyoung', 'Buckingham Palace', 'Liz Truss', 'Formula 1', 'Tom Hiddleston', 'Lando']

# %%
# are there any common ones?
ny_trends_set = set(ny_trends_list)
lo_trends_set = set(lo_trends_list)

common_trends = ny_trends_set.intersection(lo_trends_set)

print(common_trends)
# Out:
# {'Daily Quordle 157', 'Killing in the Name', 'wooyoung', 'Everton', 'Tom Hiddleston', 'Conte', 'Richarlison', 'Snake Island'}

# %%
# search #Bitcoin

bitcoin_tweets = twitter_api.search.tweets(q='#Bitcoin')

# View the output.
import json
print(json.dumps(bitcoin_tweets, indent=4))
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Thu Jun 30 13:11:45 +0000 2022",
#             "id": 1542496108487868418,
#             "id_str": "1542496108487868418",
#             "text": "RT @Shealan: @umbrel new fan, who dis? #bitcoin #LightningNetwork https://t.co/k517BjKXki",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "bitcoin",
#                         "indices": [
#                             39,
#                             47
#                         ]
#                     },
#                     {
#                         "text": "LightningNetwork",
#                         "indices": [
#                             48,
#                             65
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Shealan",
#                         "name": "SH\u039eALAN.eth",
#                         "id": 13680002,
#                         "id_str": "13680002",
#                         "indices": [
#                             3,
#                             11
#                         ]
#                     },
#                     {
#                         "screen_name": "umbrel",
#                         "name": "Umbrel \u2602\ufe0f",
#                         "id": 1212297404268994562,
#                         "id_str": "1212297404268994562",
#                         "indices": [
#                             13,
#                             20
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1542488529120677889,
#                         "id_str": "1542488529120677889",
#                         "indices": [
#                             66,
#                             89
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                         "url": "https://t.co/k517BjKXki",
#                         "display_url": "pic.twitter.com/k517BjKXki",
#                         "expanded_url": "https://twitter.com/Shealan/status/1542488539602239488/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 510,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1536,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 900,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542488539602239488,
#                         "source_status_id_str": "1542488539602239488",
#                         "source_user_id": 13680002,
#                         "source_user_id_str": "13680002"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1542488529120677889,
#                         "id_str": "1542488529120677889",
#                         "indices": [
#                             66,
#                             89
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                         "url": "https://t.co/k517BjKXki",
#                         "display_url": "pic.twitter.com/k517BjKXki",
#                         "expanded_url": "https://twitter.com/Shealan/status/1542488539602239488/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 510,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1536,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 900,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542488539602239488,
#                         "source_status_id_str": "1542488539602239488",
#                         "source_user_id": 13680002,
#                         "source_user_id_str": "13680002"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1212297404268994562,
#                 "id_str": "1212297404268994562",
#                 "name": "Umbrel \u2602\ufe0f",
#                 "screen_name": "umbrel",
#                 "location": "raspberry pi",
#                 "description": "A beautiful personal server OS for self-hosting. Run open-source apps like Nextcloud, Bitcoin/Lightning node, and more \u2192 https://t.co/cx9ikTAelv",
#                 "url": "https://t.co/Y8ayOgylC9",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/Y8ayOgylC9",
#                                 "expanded_url": "https://umbrel.com",
#                                 "display_url": "umbrel.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/cx9ikTAelv",
#                                 "expanded_url": "http://umbrel.com",
#                                 "display_url": "umbrel.com",
#                                 "indices": [
#                                     121,
#                                     144
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 45296,
#                 "friends_count": 1,
#                 "listed_count": 645,
#                 "created_at": "Wed Jan 01 09:00:05 +0000 2020",
#                 "favourites_count": 17640,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 12271,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1491113151718256641/oLgvo9w7_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1491113151718256641/oLgvo9w7_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1212297404268994562/1654792739",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 12:41:40 +0000 2022",
#                 "id": 1542488539602239488,
#                 "id_str": "1542488539602239488",
#                 "text": "@umbrel new fan, who dis? #bitcoin #LightningNetwork https://t.co/k517BjKXki",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "bitcoin",
#                             "indices": [
#                                 26,
#                                 34
#                             ]
#                         },
#                         {
#                             "text": "LightningNetwork",
#                             "indices": [
#                                 35,
#                                 52
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [
#                         {
#                             "screen_name": "umbrel",
#                             "name": "Umbrel \u2602\ufe0f",
#                             "id": 1212297404268994562,
#                             "id_str": "1212297404268994562",
#                             "indices": [
#                                 0,
#                                 7
#                             ]
#                         }
#                     ],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1542488529120677889,
#                             "id_str": "1542488529120677889",
#                             "indices": [
#                                 53,
#                                 76
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                             "url": "https://t.co/k517BjKXki",
#                             "display_url": "pic.twitter.com/k517BjKXki",
#                             "expanded_url": "https://twitter.com/Shealan/status/1542488539602239488/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "small": {
#                                     "w": 680,
#                                     "h": 510,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1536,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 900,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "id": 1542488529120677889,
#                             "id_str": "1542488529120677889",
#                             "indices": [
#                                 53,
#                                 76
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/FWgFJRBaUAEjC2X.jpg",
#                             "url": "https://t.co/k517BjKXki",
#                             "display_url": "pic.twitter.com/k517BjKXki",
#                             "expanded_url": "https://twitter.com/Shealan/status/1542488539602239488/photo/1",
#                             "type": "photo",
#                             "sizes": {
#                                 "small": {
#                                     "w": 680,
#                                     "h": 510,
#                                     "resize": "fit"
#                                 },
#                                 "thumb": {
#                                     "w": 150,
#                                     "h": 150,
#                                     "resize": "crop"
#                                 },
#                                 "large": {
#                                     "w": 2048,
#                                     "h": 1536,
#                                     "resize": "fit"
#                                 },
#                                 "medium": {
#                                     "w": 1200,
#                                     "h": 900,
#                                     "resize": "fit"
#                                 }
#                             }
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://tapbots.com/tweetbot\" rel=\"nofollow\">Tweetbot for i\u039fS</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": 1212297404268994562,
#                 "in_reply_to_user_id_str": "1212297404268994562",
#                 "in_reply_to_screen_name": "umbrel",
#                 "user": {
#                     "id": 13680002,
#                     "id_str": "13680002",
#                     "name": "SH\u039eALAN.eth",
#                     "screen_name": "Shealan",
#                     "location": "The Internet",
#                     "description": "Sydney based Full Stack Developer / Designer / Creative Technologist. Ex @fabriclondon head of tech. DJ as @phatplastic. Crypto nerd. Hot sauce addict.",
#                     "url": "https://t.co/svBU4t5s4V",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/svBU4t5s4V",
#                                     "expanded_url": "https://shealan.com",
#                                     "display_url": "shealan.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2183,
#                     "friends_count": 2327,
#                     "listed_count": 125,
#                     "created_at": "Tue Feb 19 17:18:22 +0000 2008",
#                     "favourites_count": 2073,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 42827,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "CCCCCC",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1489008799688331265/ZtTTsQVC_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1489008799688331265/ZtTTsQVC_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/13680002/1630472424",
#                     "profile_link_color": "666666",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "333333",
#                     "profile_text_color": "999999",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 1,
#                 "favorite_count": 1,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Thu Jun 30 13:11:44 +0000 2022",
#             "id": 1542496105577197568,
#             "id_str": "1542496105577197568",
#             "text": "The biggest feature of blockchain technology is data tamper resistance and decentralization (combined with the actu\u2026 https://t.co/bjwzDILhqW",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/bjwzDILhqW",
#                         "expanded_url": "https://twitter.com/i/web/status/1542496105577197568",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             117,
#                             140
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 392257103,
#                 "id_str": "392257103",
#                 "name": "yyao-lydia",
#                 "screen_name": "ayao_lydia",
#                 "location": "Singapore, Miami, USA, Taiwan",
#                 "description": "Entrepreneur, Investor, Regional Sales Director\nFocus on Retail, Fast Fashion, Design, Wholesales and E-Commerce\n#traveling  #reading #swimming\n#100% backfollow",
#                 "url": "https://t.co/c9HfxeYsjk",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/c9HfxeYsjk",
#                                 "expanded_url": "https://www.charleskeith.com",
#                                 "display_url": "charleskeith.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 693,
#                 "friends_count": 691,
#                 "listed_count": 1,
#                 "created_at": "Sun Oct 16 19:26:35 +0000 2011",
#                 "favourites_count": 4605,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 65,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "131516",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#                 "profile_background_tile": true,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1532220428319858689/2NsGpRyD_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1532220428319858689/2NsGpRyD_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/392257103/1646101499",
#                 "profile_link_color": "009999",
#                 "profile_sidebar_border_color": "EEEEEE",
#                 "profile_sidebar_fill_color": "EFEFEF",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Thu Jun 30 13:11:44 +0000 2022",
#             "id": 1542496105560125440,
#             "id_str": "1542496105560125440",
#             "text": "RT @Oxrollntrip: \ud83d\udc23 Pour c\u00e9l\u00e9brer mon arriv\u00e9e sur twitter, j\u2019offre $100 en $USDT \ud83d\udcb5\n\n2 Gagnants\ud83d\udc47\nLike \u2764\ufe0f RT \ud83c\udf81 Follow: @Oxrollntrip (\ud83d\udd14)\n\n#Conc\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [
#                     {
#                         "text": "USDT",
#                         "indices": [
#                             74,
#                             79
#                         ]
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Oxrollntrip",
#                         "name": "Willroll.eth \u2728\ud83e\udd87\ud83d\udd0a",
#                         "id": 1163165131360165888,
#                         "id_str": "1163165131360165888",
#                         "indices": [
#                             3,
#                             15
#                         ]
#                     },
#                     {
#                         "screen_name": "Oxrollntrip",
#                         "name": "Willroll.eth \u2728\ud83e\udd87\ud83d\udd0a",
#                         "id": 1163165131360165888,
#                         "id_str": "1163165131360165888",
#                         "indices": [
#                             116,
#                             128
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "fr",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1538256025152651264,
#                 "id_str": "1538256025152651264",
#                 "name": "SiwakwowNft",
#                 "screen_name": "SiwakwowNft",
#                 "location": "England, United Kingdom",
#                 "description": "TesGiveaway Hunter_\nCrypto. #XRPL #Solana #BTC #ETH #NFT #NOTIGANG #NOTISQUAD #NotiFam #SOLGANG #STX",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 10,
#                 "friends_count": 1556,
#                 "listed_count": 0,
#                 "created_at": "Sat Jun 18 20:23:25 +0000 2022",
#                 "favourites_count": 3517,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 3986,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1538349181525364736/Tljuqzu6_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1538349181525364736/Tljuqzu6_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1538256025152651264/1655603116",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Wed Jun 29 13:54:07 +0000 2022",
#                 "id": 1542144384770183168,
#                 "id_str": "1542144384770183168",
#                 "text": "\ud83d\udc23 Pour c\u00e9l\u00e9brer mon arriv\u00e9e sur twitter, j\u2019offre $100 en $USDT \ud83d\udcb5\n\n2 Gagnants\ud83d\udc47\nLike \u2764\ufe0f RT \ud83c\udf81 Follow: @Oxrollntrip (\ud83d\udd14)\u2026 https://t.co/HgmFb0XM4z",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [
#                         {
#                             "text": "USDT",
#                             "indices": [
#                                 57,
#                                 62
#                             ]
#                         }
#                     ],
#                     "user_mentions": [
#                         {
#                             "screen_name": "Oxrollntrip",
#                             "name": "Willroll.eth \u2728\ud83e\udd87\ud83d\udd0a",
#                             "id": 1163165131360165888,
#                             "id_str": "1163165131360165888",
#                             "indices": [
#                                 99,
#                                 111
#                             ]
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "url": "https://t.co/HgmFb0XM4z",
#                             "expanded_url": "https://twitter.com/i/web/status/1542144384770183168",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "fr",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1163165131360165888,
#                     "id_str": "1163165131360165888",
#                     "name": "Willroll.eth \u2728\ud83e\udd87\ud83d\udd0a",
#                     "screen_name": "Oxrollntrip",
#                     "location": "",
#                     "description": "Marre de voir des fakes crypo-experts \ud83d\ude12. J\u2019investis en Crypto depuis 2016. Surv\u00e9cu 2 bear market \ud83d\udc3b. Il est temps de partager de vrais conseils \ud83d\udcc8\ud83d\udcc9\ud83d\udcc8",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 313,
#                     "friends_count": 10,
#                     "listed_count": 0,
#                     "created_at": "Sun Aug 18 19:06:04 +0000 2019",
#                     "favourites_count": 51,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 26,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1431877470589014017/LT9Neby4_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1431877470589014017/LT9Neby4_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1163165131360165888/1656488370",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 330,
#                 "favorite_count": 358,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "fr"
#             },
#             "is_quote_status": false,
#             "retweet_count": 330,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "fr"
#         },
#         {
#             "created_at": "Thu Jun 30 13:11:44 +0000 2022",
#             "id": 1542496104977244162,
#             "id_str": "1542496104977244162",
#             "text": "RT @aybukenazyasasn: #ya\u015famhakk\u0131m \u00f6lmek istemiyorum. \nVe sizlere ihtiyac\u0131m var l\u00fctfen beni g\u00f6r\u00fcn\n\n#SONDAK\u0130KA #Binance #Bitcoin #ademkilicci\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "ya\u015famhakk\u0131m",
#                         "indices": [
#                             21,
#                             33
#                         ]
#                     },
#                     {
#                         "text": "SONDAK\u0130KA",
#                         "indices": [
#                             98,
#                             108
#                         ]
#                     },
#                     {
#                         "text": "Binance",
#                         "indices": [
#                             109,
#                             117
#                         ]
#                     },
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             118,
#                             126
#                         ]
#                     },
#                     {
#                         "text": "ademkilicci",
#                         "indices": [
#                             127,
#                             139
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "aybukenazyasasn",
#                         "name": "AYKIZ YA\u015eASIN\ud83c\udf19|SMA T\u0130P 1",
#                         "id": 1432758225909190658,
#                         "id_str": "1432758225909190658",
#                         "indices": [
#                             3,
#                             19
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "recent",
#                 "iso_language_code": "tr"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2272685647,
#                 "id_str": "2272685647",
#                 "name": "Aynur Zeren",
#                 "screen_name": "aynur_zeren",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 71,
#                 "friends_count": 79,
#                 "listed_count": 0,
#                 "created_at": "Thu Jan 02 08:04:05 +0000 2014",
#                 "favourites_count": 5568,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 3303,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/434616822835331072/EinOi2lh_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/434616822835331072/EinOi2lh_normal.jpeg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2272685647/1576246256",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 09:51:34 +0000 2022",
#                 "id": 1542445731428155393,
#                 "id_str": "1542445731428155393",
#                 "text": "#ya\u015famhakk\u0131m \u00f6lmek istemiyorum. \nVe sizlere ihtiyac\u0131m var l\u00fctfen beni g\u00f6r\u00fcn\n\n#SONDAK\u0130KA #Binance #Bitcoin\u2026 https://t.co/YPciE7uLv4",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "ya\u015famhakk\u0131m",
#                             "indices": [
#                                 0,
#                                 12
#                             ]
#                         },
#                         {
#                             "text": "SONDAK\u0130KA",
#                             "indices": [
#                                 77,
#                                 87
#                             ]
#                         },
#                         {
#                             "text": "Binance",
#                             "indices": [
#                                 88,
#                                 96
#                             ]
#                         },
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 97,
#                                 105
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [
#                         {
#                             "url": "https://t.co/YPciE7uLv4",
#                             "expanded_url": "https://twitter.com/i/web/status/1542445731428155393",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 107,
#                                 130
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "result_type": "recent",
#                     "iso_language_code": "tr"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1432758225909190658,
#                     "id_str": "1432758225909190658",
#                     "name": "AYKIZ YA\u015eASIN\ud83c\udf19|SMA T\u0130P 1",
#                     "screen_name": "aybukenazyasasn",
#                     "location": "Adana, T\u00fcrkiye",
#                     "description": "FAAL\u0130YET kod 21-623 Taplink hesab\u0131mz\u2935\ufe0f https://t.co/C8gWz3Kl1X                                    \n\n9805 e AYKIZ yaz\u0131p g\u00f6nderebilirsiniz.1sms 20 TL",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/C8gWz3Kl1X",
#                                     "expanded_url": "https://taplink.cc/aybukenaz_yasasin",
#                                     "display_url": "taplink.cc/aybukenaz_yasa\u2026",
#                                     "indices": [
#                                         39,
#                                         62
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2912,
#                     "friends_count": 3127,
#                     "listed_count": 0,
#                     "created_at": "Tue Aug 31 17:32:43 +0000 2021",
#                     "favourites_count": 551,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 1370,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1539858276682240000/-oYAP23c_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1539858276682240000/-oYAP23c_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1432758225909190658/1656493092",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 203,
#                 "favorite_count": 283,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "tr"
#             },
#             "is_quote_status": false,
#             "retweet_count": 203,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "tr"
#         },
#         {
#             "created_at": "Thu Jun 30 13:11:44 +0000 2022",
#             "id": 1542496104423591940,
#             "id_str": "1542496104423591940",
#             "text": "RT @Dennis_Porter_: I\u2019m extremely hopeful because of #Bitcoin. Without it, the future would look extremely dark.",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             53,
#                             61
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Dennis_Porter_",
#                         "name": "Dennis Porter",
#                         "id": 1291243382128304133,
#                         "id_str": "1291243382128304133",
#                         "indices": [
#                             3,
#                             18
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2909648240,
#                 "id_str": "2909648240",
#                 "name": "Marlau Invest (Marlaunomics)",
#                 "screen_name": "marlaukoss",
#                 "location": "Not Financial Advice",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 25,
#                 "friends_count": 121,
#                 "listed_count": 7,
#                 "created_at": "Tue Nov 25 04:52:09 +0000 2014",
#                 "favourites_count": 259,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 385,
# ...
#                                 38,
#                                 46
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": []
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 361289499,
#                     "id_str": "361289499",
#                     "name": "Bitcoin Magazine",
#                     "screen_name": "BitcoinMagazine",
#                     "location": "Nashville, TN",
#                     "description": "The Most Trusted Voice In #Bitcoin \u2022  World's Largest Bitcoin Conference \ud83c\udf9f https://t.co/hBUM3ottXO \u2022 Shop \ud83d\udcd7 https://t.co/v3sTyHVZKV \u2022 Find us \ud83d\udd0e https://t.co/X4mXn3XUAg",
#                     "url": "https://t.co/UPj0DC9NOU",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/UPj0DC9NOU",
#                                     "expanded_url": "http://BitcoinMagazine.com",
#                                     "display_url": "BitcoinMagazine.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/hBUM3ottXO",
#                                     "expanded_url": "http://b.tc/conference/2023",
#                                     "display_url": "b.tc/conference/2023",
#                                     "indices": [
#                                         75,
#                                         98
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/v3sTyHVZKV",
#                                     "expanded_url": "http://b.tc/store",
#                                     "display_url": "b.tc/store",
#                                     "indices": [
#                                         108,
#                                         131
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/X4mXn3XUAg",
#                                     "expanded_url": "http://linktr.ee/btcinc",
#                                     "display_url": "linktr.ee/btcinc",
#                                     "indices": [
#                                         144,
#                                         167
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2548367,
#                     "friends_count": 770,
#                     "listed_count": 13920,
#                     "created_at": "Wed Aug 24 15:14:54 +0000 2011",
#                     "favourites_count": 25878,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": true,
#                     "statuses_count": 23822,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1444022922377576453/AzvXYXGr_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1444022922377576453/AzvXYXGr_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/361289499/1655991595",
#                     "profile_link_color": "FFA207",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "has_extended_profile": false,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "regular",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 539,
#                 "favorite_count": 3105,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 539,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Thu Jun 30 13:11:38 +0000 2022",
#             "id": 1542496081854214144,
#             "id_str": "1542496081854214144",
#             "text": "RT @nibiruverseio: Set up your alarm - Nibiruverse on Pinksale. \n.\nhttps://t.co/zceH8q6BCD\nStart : July 1. 2022 - 15.00 UTC Until July 3. 2\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "nibiruverseio",
#                         "name": "Nibiruverse Official",
#                         "id": 1539715355269967872,
#                         "id_str": "1539715355269967872",
#                         "indices": [
#                             3,
#                             17
#                         ]
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/zceH8q6BCD",
#                         "expanded_url": "https://pinksale.finance/launchpad/0xA5D5A3fd214312d7d73fc41639c09d93274A858A?chain=BSC",
#                         "display_url": "pinksale.finance/launchpad/0xA5\u2026",
#                         "indices": [
#                             67,
#                             90
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1366409170472210432,
#                 "id_str": "1366409170472210432",
#                 "name": "\ubbfc \uaddc\ud83d\udcb0\ud83d\udcb0\ud83d\udcb0\ud83d\udcb0 \u26a1 #BNBChain",
#                 "screen_name": "Twinkle96991189",
#                 "location": "",
#                 "description": "YouTuber\n#BNBChain",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 64,
#                 "friends_count": 2252,
#                 "listed_count": 1,
#                 "created_at": "Mon Mar 01 15:25:18 +0000 2021",
#                 "favourites_count": 3188,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 9651,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1514730698602545166/dIoM6AoE_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1514730698602545166/dIoM6AoE_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1366409170472210432/1618083077",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 08:27:43 +0000 2022",
#                 "id": 1542424631151173632,
#                 "id_str": "1542424631151173632",
#                 "text": "Set up your alarm - Nibiruverse on Pinksale. \n.\nhttps://t.co/zceH8q6BCD\nStart : July 1. 2022 - 15.00 UTC Until July\u2026 https://t.co/2bSLE1JGQk",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [
#                         {
#                             "url": "https://t.co/zceH8q6BCD",
#                             "expanded_url": "https://pinksale.finance/launchpad/0xA5D5A3fd214312d7d73fc41639c09d93274A858A?chain=BSC",
#                             "display_url": "pinksale.finance/launchpad/0xA5\u2026",
#                             "indices": [
#                                 48,
#                                 71
#                             ]
#                         },
#                         {
#                             "url": "https://t.co/2bSLE1JGQk",
#                             "expanded_url": "https://twitter.com/i/web/status/1542424631151173632",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1539715355269967872,
#                     "id_str": "1539715355269967872",
#                     "name": "Nibiruverse Official",
#                     "screen_name": "nibiruverseio",
#                     "location": "",
#                     "description": "Be the \"God of the God\" of Nibiru Verse.",
#                     "url": null,
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 5872,
#                     "friends_count": 1,
#                     "listed_count": 1,
#                     "created_at": "Wed Jun 22 21:02:12 +0000 2022",
#                     "favourites_count": 0,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 15,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1542108611283144707/h6Dpz5nI_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1542108611283144707/h6Dpz5nI_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1539715355269967872/1656502306",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 4016,
#                 "favorite_count": 4487,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 4016,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.129,
#         "max_id": 1542496108487868418,
#         "max_id_str": "1542496108487868418",
#         "next_results": "?max_id=1542496081854214143&q=%23Bitcoin&include_entities=1",
#         "query": "%23Bitcoin",
#         "refresh_url": "?since_id=1542496108487868418&q=%23Bitcoin&include_entities=1",
#         "count": 15,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }
